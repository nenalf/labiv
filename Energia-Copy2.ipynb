# %% [raw]
# Importando bibliotecas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# Leitura dos arquivos csv

# %%
coleta2013_a = pd.read_csv('coleta2013_amostrado.csv', sep=',')

# %%
coleta2023_a = pd.read_csv('coleta2023_amostrado.csv', sep=',')

# %%
coleta2013_a
# Out:
#       id_subsistema id_estado nom_localizacao nom_tipousina  \
# 0                NE        CE         Litoral        Eólica
# 1                NE        CE         Litoral        Eólica
# 2                NE        RN         Litoral        Eólica
# 3                NE        RN         Litoral        Eólica
# 4                NE        RN         Litoral        Eólica
# ...             ...       ...             ...           ...
# 24305            NE        RN         Litoral        Eólica
# 24306            NE        RN         Litoral        Eólica
# 24307            NE        RN         Litoral        Eólica
# 24308            NE        RN         Litoral        Eólica
# 24309            NE        RN         Litoral        Eólica
#
#        val_geracaoprogramada  val_geracaoverificada  val_capacidadeinstalada  \
# 0                       16.0                  0.942                   105.00
# 1                       38.0                  7.758                   105.00
# 2                       20.0                 21.749                    51.00
# 3                       39.0                 37.069                    51.00
# 4                        8.5                  3.931                    51.00
# ...                      ...                    ...                      ...
# 24305                   10.0                 19.784                    51.00
# 24306                    7.0                 19.039                   100.65
# 24307                    6.5                  4.531                   100.65
# 24308                    0.0                  0.000                    68.47
# 24309                   37.0                 41.503                    51.00
#
#        val_fatorcapacidade   ano  mes     id
# 0                 0.008971  2013    1   3017
# 1                 0.073886  2013    4  12672
# 2                 0.426451  2013    7  23608
# 3                 0.726843  2013    3   8248
# 4                 0.077078  2013    7  24863
# ...                    ...   ...  ...    ...
# 24305             0.387922  2013    6  18928
# 24306             0.189160  2013    4  13904
# 24307             0.045017  2013    9  32304
# 24308             0.000000  2013   12  43240
# 24309             0.813784  2013   12  47014
#
# [24310 rows x 11 columns]

# %% [markdown]
# A partir daqui, começa-se o tratamento de dados para redução das colunas.
# Em um primeiro momento, será feito o tratamento da coluna data, para que os carimbos de hora sejam separados e posteriormente descartados como as demais colunas que não serão utilizadas

# %%
coleta2023_a
# Out:
#       id_subsistema id_estado nom_localizacao nom_tipousina  \
# 0                NE        RN         Litoral        Eólica
# 1                NE        RN         Litoral        Eólica
# 2                NE        CE        Interior        Eólica
# 3                NE        RN         Litoral        Eólica
# 4                SE        MG             NaN         Solar
# ...             ...       ...             ...           ...
# 20628             S        RS             NaN        Eólica
# 20629            NE        BA        Interior        Eólica
# 20630            NE        BA        Interior        Eólica
# 20631            NE        RN         Litoral        Eólica
# 20632            NE        CE        Interior        Eólica
#
#        val_geracaoprogramada  val_geracaoverificada  val_capacidadeinstalada  \
# 0                       41.5                 55.571                  250.485
# 1                       72.5                102.388                  218.700
# 2                       18.5                 36.545                   86.100
# 3                      120.0                115.342                  211.365
# 4                        0.0                  0.000                   88.400
# ...                      ...                    ...                      ...
# 20628                  283.5                299.933                  317.900
# 20629                   35.5                 18.815                  303.000
# 20630                  241.5                263.502                  303.000
# 20631                   28.0                 44.888                  234.700
# 20632                   31.5                 35.730                  133.330
#
#        val_fatorcapacidade        data   ano  mes       id
# 0                 0.221854  2023-05-10  2023    5   593065
# 1                 0.468166  2023-05-23  2023    5   655275
# 2                 0.424448  2023-05-02  2023    5   557533
# 3                 0.545701  2023-06-11  2023    6   741308
# 4                 0.000000  2023-05-18  2023    5   632351
# ...                    ...         ...   ...  ...      ...
# 20628             0.943482  2023-12-12  2023   12  1624517
# 20629             0.062096  2023-10-25  2023   10  1391909
# 20630             0.869644  2023-05-04  2023    5   563944
# 20631             0.191257  2023-03-26  2023    3   381572
# 20632             0.267982  2023-12-15  2023   12  1639116
#
# [20633 rows x 12 columns]

# %% [markdown]
# Agregando datasets

# %%
file_paths = [
    "coleta2013_amostrado.csv",
    "coleta2023_amostrado.csv",
]

# %%
coletatotal = pd.DataFrame()

for file_path in file_paths:
    data_df = pd.read_csv(file_path, sep=',',error_bad_lines=False)
    coletatotal = coletatotal.append(data_df)
# Out:
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_10664\2765651162.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=',',error_bad_lines=False)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_10664\2765651162.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coletatotal = coletatotal.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_10664\2765651162.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=',',error_bad_lines=False)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_10664\2765651162.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coletatotal = coletatotal.append(data_df)

# %%
coletatotal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44943 entries, 0 to 20632
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_subsistema            44943 non-null  object
#  1   id_estado                44943 non-null  object
#  2   nom_localizacao          37747 non-null  object
#  3   nom_tipousina            44943 non-null  object
#  4   val_geracaoprogramada    44330 non-null  float64
#  5   val_geracaoverificada    44943 non-null  float64
#  6   val_capacidadeinstalada  44774 non-null  float64
#  7   val_fatorcapacidade      44943 non-null  float64
#  8   ano                      44943 non-null  int64
#  9   mes                      44943 non-null  int64
#  10  id                       44943 non-null  int64
#  11  data                     20633 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 4.5+ MB

# %% [markdown]
# Agrupando por mês e ano para

# %%
dimtempo = coletatotal[['mes', 'ano','id']]

# %%
dimtempo
# Out:
#        mes   ano       id
# 0        1  2013     3017
# 1        4  2013    12672
# 2        7  2013    23608
# 3        3  2013     8248
# 4        7  2013    24863
# ...    ...   ...      ...
# 20628   12  2023  1624517
# 20629   10  2023  1391909
# 20630    5  2023   563944
# 20631    3  2023   381572
# 20632   12  2023  1639116
#
# [44943 rows x 3 columns]

# %%
dimfonte = coletatotal[['nom_tipousina','id']]

# %%
dimfonte
# Out:
#       nom_tipousina       id
# 0            Eólica     3017
# 1            Eólica    12672
# 2            Eólica    23608
# 3            Eólica     8248
# 4            Eólica    24863
# ...             ...      ...
# 20628        Eólica  1624517
# 20629        Eólica  1391909
# 20630        Eólica   563944
# 20631        Eólica   381572
# 20632        Eólica  1639116
#
# [44943 rows x 2 columns]

# %%
dimloc = coletatotal[['id_subsistema', 'id_estado', 'nom_localizacao','id']]

# %%
dimloc
# Out:
#       id_subsistema id_estado nom_localizacao       id
# 0                NE        CE         Litoral     3017
# 1                NE        CE         Litoral    12672
# 2                NE        RN         Litoral    23608
# 3                NE        RN         Litoral     8248
# 4                NE        RN         Litoral    24863
# ...             ...       ...             ...      ...
# 20628             S        RS             NaN  1624517
# 20629            NE        BA        Interior  1391909
# 20630            NE        BA        Interior   563944
# 20631            NE        RN         Litoral   381572
# 20632            NE        CE        Interior  1639116
#
# [44943 rows x 4 columns]

# %%
dimtempo.to_csv('dimtempo_a.csv', index=True)

# %%
dimloc.to_csv('dimloc_a.csv', index=True)

# %%
dimfonte.to_csv('dimfonte_a.csv', index=True)

# %%
coletatotal.to_csv('coletatotal_a.csv', index=True)
