# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# Leitura dos arquivos csv

# %%
coleta2009 = pd.read_csv('Documents/FATOR_CAPACIDADE_2009.csv', sep=';')

# %%
coleta2010 = pd.read_csv('Documents/FATOR_CAPACIDADE_2010.csv', sep=';')
coleta2011 = pd.read_csv('Documents/FATOR_CAPACIDADE_2011.csv', sep=';')
coleta2012 = pd.read_csv('Documents/FATOR_CAPACIDADE_2012.csv', sep=';')
coleta2013 = pd.read_csv('Documents/FATOR_CAPACIDADE_2013.csv', sep=';')
coleta2014 = pd.read_csv('Documents/FATOR_CAPACIDADE_2014.csv', sep=';')
coleta2015 = pd.read_csv('Documents/FATOR_CAPACIDADE_2015.csv', sep=';')
coleta2016 = pd.read_csv('Documents/FATOR_CAPACIDADE_2016.csv', sep=';')
coleta2017 = pd.read_csv('Documents/FATOR_CAPACIDADE_2017.csv', sep=';')
coleta2018 = pd.read_csv('Documents/FATOR_CAPACIDADE_2018.csv', sep=';')
coleta2019 = pd.read_csv('Documents/FATOR_CAPACIDADE_2019.csv', sep=';')
coleta2020 = pd.read_csv('Documents/FATOR_CAPACIDADE_2020.csv', sep=';')
coleta2021 = pd.read_csv('Documents/FATOR_CAPACIDADE_2021.csv', sep=';')

# %% [markdown]
# Criação de lista com os caminhos dos arquivos csv de cada mês do ano de 2002

# %%
file_paths = [
    "Documents/FATOR_CAPACIDADE-2_2022_01.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_02.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_03.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_04.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_05.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_06.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_07.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_08.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_09.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_10.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_11.csv",
    "Documents/FATOR_CAPACIDADE-2_2022_12.csv",
]

# %% [markdown]
# Junção dos arquivos de meses e exportando para um unico csv referente às coletas do anos de 2022

# %%
# Criar DataFrame vazio
combined_df = pd.DataFrame()

# Iterar e anexar dados
for file_path in file_paths:
    data_df = pd.read_csv(file_path)
    combined_df = combined_df.append(data_df)
# Out:
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3515670146.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3515670146.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3515670146.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3515670146.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(data_df)
# ...

# %%
combined_df
# Out:
#        id_subsistema;nom_subsistema;id_estado;nom_estado;nom_pontoconexao;nom_localizacao;val_latitudesecoletora;val_longitudesecoletora;val_latitudepontoconexao;val_longitudepontoconexao;nom_modalidadeoperacao;nom_tipousina;nom_usina_conjunto;id_ons;ceg;din_instante;val_geracaoprogramada;val_geracaoverificada;val_capacidadeinstalada;val_fatorcapacidade
# 0       N;Norte;MA;MARANHAO;MIRANDA II500kVA;;-2.72722...
# 1       NE;Nordeste;BA;BAHIA;PINDAI II - 230 kV (A);In...
# 2       NE;Nordeste;BA;BAHIA;IGAPORA II - 69 kV (A);In...
# 3       NE;Nordeste;BA;BAHIA;IGAPORA II - 230 kV (B);I...
# 4       NE;Nordeste;BA;BAHIA;U.SOBRADINHO - 500 kV (A)...
# ...                                                   ...
# 137491  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;COL BOA H...
# 137492  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;DRACENA -...
# 137493  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;GETULINA ...
# 137494  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;AGUA VERM...
# ...

# %% [markdown]
# A mensagem na caixa vermelha é apenas uma orientação da biblioteca pandas, não afetando o resultado do comando.
#
# A primeira junção teve erro na leitura, não formou tabela, logo, serão feitas tentativas de resolução.

# %%
coleta2022 = pd.DataFrame()

for file_path in file_paths:
    data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
    coleta2022 = coleta2022.append(data_df)
# Out:
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3486878437.py:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3486878437.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coleta2022 = coleta2022.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\3486878437.py:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
# ...

# %%
coleta2022
# Out:
#        id_subsistema        nom_subsistema id_estado nom_estado  \
# 0                  N                 Norte        MA   MARANHAO
# 1                 NE              Nordeste        BA      BAHIA
# 2                 NE              Nordeste        BA      BAHIA
# 3                 NE              Nordeste        BA      BAHIA
# 4                 NE              Nordeste        BA      BAHIA
# ...              ...                   ...       ...        ...
# 137491            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 137492            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 137493            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 137494            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 137495            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
#
#                   nom_pontoconexao nom_localizacao val_latitudesecoletora  \
# 0                 MIRANDA II500kVA             NaN              -2.727222
# ...

# %% [markdown]
# Acima é visto que o problema foi resolvido e, ainda que tenha sido usado um código para ignorar erro de leitura, somente uma linha foi afetada, o que não vai atrapalhar a análise.
# Abaixo, o mesmo caminho é feito para o ano de 2023.

# %%
file_paths = [
    "Documents/FATOR_CAPACIDADE-2_2023_01.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_02.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_03.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_04.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_05.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_06.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_07.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_08.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_09.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_10.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_11.csv",
    "Documents/FATOR_CAPACIDADE-2_2023_12.csv",
]

# %%
coleta2023 = pd.DataFrame()

for file_path in file_paths:
    data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
    coleta2023 = coleta2023.append(data_df)
# Out:
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\2411747975.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\2411747975.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coleta2023 = coleta2023.append(data_df)
# C:\Users\Lorena\AppData\Local\Temp\ipykernel_14196\2411747975.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_df = pd.read_csv(file_path, sep=';',error_bad_lines=False)
# ...

# %%
coleta2023
# Out:
#        id_subsistema;nom_subsistema;id_estado;nom_estado;nom_pontoconexao;nom_localizacao;val_latitudesecoletora;val_longitudesecoletora;val_latitudepontoconexao;val_longitudepontoconexao;nom_modalidadeoperacao;nom_tipousina;nom_usina_conjunto;id_ons;ceg;din_instante;val_geracaoprogramada;val_geracaoverificada;val_capacidadeinstalada;val_fatorcapacidade
# 0       N;Norte;MA;MARANHAO;MIRANDA II500kVA;;-2.72722...
# 1       NE;Nordeste;BA;BAHIA;PINDAI II - 230 kV (A);In...
# 2       NE;Nordeste;BA;BAHIA;IGAPORA III - 500 kV (A);...
# 3       NE;Nordeste;BA;BAHIA;IGAPORA II - 230 kV (B);I...
# 4       NE;Nordeste;BA;BAHIA;U.SOBRADINHO - 500 kV (A)...
# ...                                                   ...
# 151267  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;TRES IRMA...
# 151268  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;DRACENA -...
# 151269  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;GETULINA ...
# 151270  SE;Sudeste/Centro-Oeste;SP;SAO PAULO;AGUA VERM...
# ...

# %%
coleta2023
# Out:
#        id_subsistema        nom_subsistema id_estado nom_estado  \
# 0                  N                 Norte        MA   MARANHAO
# 1                 NE              Nordeste        BA      BAHIA
# 2                 NE              Nordeste        BA      BAHIA
# 3                 NE              Nordeste        BA      BAHIA
# 4                 NE              Nordeste        BA      BAHIA
# ...              ...                   ...       ...        ...
# 151267            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 151268            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 151269            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 151270            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 151271            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
#
#                   nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 0                 MIRANDA II500kVA             NaN               -2.727222
# ...

# %% [markdown]
# A partir daqui, começa-se o tratamento de dados para redução das colunas.
# Em um primeiro momento, será feito o tratamento da coluna data, para que os carimbos de hora sejam separados e posteriormente descartados como as demais colunas que não serão utilizadas

# %%
coleta2009[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)

# %%
coleta2009
# Out:
#      id_subsistema nom_subsistema id_estado nom_estado  \
# 0               NE       Nordeste        CE      CEARA
# 1               NE       Nordeste        CE      CEARA
# 2               NE       Nordeste        CE      CEARA
# 3               NE       Nordeste        CE      CEARA
# 4               NE       Nordeste        CE      CEARA
# ...            ...            ...       ...        ...
# 6953            NE       Nordeste        CE      CEARA
# 6954            NE       Nordeste        CE      CEARA
# 6955            NE       Nordeste        CE      CEARA
# 6956            NE       Nordeste        CE      CEARA
# 6957            NE       Nordeste        CE      CEARA
#
#              nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 0     SOBRAL III - 230 kV (A)         Litoral               -2.919422
# 1     SOBRAL III - 230 kV (A)         Litoral               -2.919422
# 2     SOBRAL III - 230 kV (A)         Litoral               -2.919422
# ...

# %%
coleta2010[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2011[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2012[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2013[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2014[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2015[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2016[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2017[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2018[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2019[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2020[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2021[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2022[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)
coleta2023[['data', 'horario']] = coleta2009['din_instante'].str.split(' ', expand=True)

# %%
coleta2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139280 entries, 0 to 1139279
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   id_subsistema            1139280 non-null  object
#  1   id_estado                1139280 non-null  object
#  2   nom_localizacao          981168 non-null   object
#  3   nom_tipousina            1139280 non-null  object
#  4   val_geracaoprogramada    1103424 non-null  float64
#  5   val_geracaoverificada    1139280 non-null  float64
#  6   val_capacidadeinstalada  1135440 non-null  float64
#  7   val_fatorcapacidade      1139280 non-null  float64
#  8   data                     6958 non-null     object
# dtypes: float64(4), object(5)
# memory usage: 78.2+ MB

# %% [markdown]
# Remoção das colunas que não serão utilizadas

# %%
colunas_para_remover = ['nom_subsistema', 'nom_estado', 'nom_pontoconexao', 'val_latitudesecoletora', 'val_longitudesecoletora', 
                        'val_latitudepontoconexao','val_longitudepontoconexao','nom_modalidadeoperacao','nom_usina_conjunto',
                       'id_ons','ceg','din_instante','horario']
coleta2020 = coleta2020.drop(columns=colunas_para_remover)

# %%
coleta2020
# Out:
#         id_subsistema id_estado nom_localizacao nom_tipousina  \
# 0                   N        MA             NaN        Eólica
# 1                  NE        BA        Interior        Eólica
# 2                  NE        BA        Interior        Eólica
# 3                  NE        BA        Interior        Eólica
# 4                  NE        BA        Interior        Eólica
# ...               ...       ...             ...           ...
# 1139275            SE        MG             NaN         Solar
# 1139276            SE        MG             NaN         Solar
# 1139277            SE        SP             NaN         Solar
# 1139278            SE        SP             NaN         Solar
# 1139279            SE        SP             NaN         Solar
#
#          val_geracaoprogramada  val_geracaoverificada  \
# 0                         75.5                 23.796
# 1                          2.0                  5.135
# 2                         12.5                 23.827
# ...

# %%
coleta2009 = coleta2009.drop(columns=colunas_para_remover)
coleta2010 = coleta2010.drop(columns=colunas_para_remover)
coleta2011 = coleta2011.drop(columns=colunas_para_remover)
coleta2012 = coleta2012.drop(columns=colunas_para_remover)
coleta2013 = coleta2013.drop(columns=colunas_para_remover)
coleta2014 = coleta2014.drop(columns=colunas_para_remover)
coleta2015 = coleta2015.drop(columns=colunas_para_remover)
coleta2016 = coleta2016.drop(columns=colunas_para_remover)
coleta2017 = coleta2017.drop(columns=colunas_para_remover)
coleta2018 = coleta2018.drop(columns=colunas_para_remover)
coleta2019 = coleta2019.drop(columns=colunas_para_remover)
coleta2021 = coleta2021.drop(columns=colunas_para_remover)
coleta2022 = coleta2022.drop(columns=colunas_para_remover)
coleta2023 = coleta2023.drop(columns=colunas_para_remover)
